# %%
import os
import pandas as pd
from tqdm import tqdm
import seaborn as sns
# %matplotlib inline

# %%
root_path = "/exp/tpinho/Datasets/US_Corn_Yield_2016"
original = "Original"

# %%
us_corn_datasets = ["US_Corn_Yield_2016_Removed_ALABAMA",
                "US_Corn_Yield_2016_Removed_ARKANSAS",
                "US_Corn_Yield_2016_Removed_CALIFORNIA",
                "US_Corn_Yield_2016_Removed_COLORADO",
                "US_Corn_Yield_2016_Removed_DELAWARE",
                "US_Corn_Yield_2016_Removed_GEORGIA",
                "US_Corn_Yield_2016_Removed_IDAHO",
                "US_Corn_Yield_2016_Removed_ILLINOIS",
                "US_Corn_Yield_2016_Removed_INDIANA",
                "US_Corn_Yield_2016_Removed_IOWA",
                "US_Corn_Yield_2016_Removed_KANSAS",
                "US_Corn_Yield_2016_Removed_KENTUCKY",
                "US_Corn_Yield_2016_Removed_LOUISIANA",
                "US_Corn_Yield_2016_Removed_MARYLAND",
                "US_Corn_Yield_2016_Removed_MICHIGAN",
                "US_Corn_Yield_2016_Removed_MINNESOTA",
                "US_Corn_Yield_2016_Removed_MISSISSIPPI",
                "US_Corn_Yield_2016_Removed_MISSOURI",
                "US_Corn_Yield_2016_Removed_MONTANA",
                "US_Corn_Yield_2016_Removed_NEBRASKA",
                "US_Corn_Yield_2016_Removed_NEW JERSEY",
                "US_Corn_Yield_2016_Removed_NEW MEXICO",
                "US_Corn_Yield_2016_Removed_NEW YORK",
                "US_Corn_Yield_2016_Removed_NORTH CAROLINA",
                "US_Corn_Yield_2016_Removed_NORTH DAKOTA",
                "US_Corn_Yield_2016_Removed_OHIO",
                "US_Corn_Yield_2016_Removed_OKLAHOMA",
                "US_Corn_Yield_2016_Removed_PENNSYLVANIA",
                "US_Corn_Yield_2016_Removed_SOUTH CAROLINA",
                "US_Corn_Yield_2016_Removed_SOUTH DAKOTA",
                "US_Corn_Yield_2016_Removed_TENNESSEE",
                "US_Corn_Yield_2016_Removed_TEXAS",
                "US_Corn_Yield_2016_Removed_VIRGINIA",
                "US_Corn_Yield_2016_Removed_WEST VIRGINIA",
                "US_Corn_Yield_2016_Removed_WISCONSIN",
                "US_Corn_Yield_2016_Removed_WYOMING"]

us_corn_datasets = ["US_Corn_Yield_2016_Removed_Northeast",
                    "US_Corn_Yield_2016_Removed_Southeast",
                    "US_Corn_Yield_2016_Removed_Midwest",
                    "US_Corn_Yield_2016_Removed_Southwest",
                    "US_Corn_Yield_2016_Removed_West"]

scv_methods = ["CrossValidation",
               "Optimistic",
               "RegGBSCV_R_Kappa_0.0",
               "RegGBSCV_R_Kappa_0.1",
               "RegGBSCV_R_Kappa_0.2",
               "RegGBSCV_R_Kappa_0.3",  
               "RegGBSCV_R_Kappa_0.4",
               "RegGBSCV_R_Kappa_0.5",
               "RegGBSCV_R_Kappa_0.6",
               "RegGBSCV_R_Kappa_0.7", 
               "RegGBSCV_R_Kappa_0.8",
               "RegGBSCV_R_Kappa_0.9",
               "RegGBSCV_R_Kappa_1.0",
               "TraditionalSCV"]

# %%
heatmap_data = pd.DataFrame(index=us_corn_datasets, columns=scv_methods, dtype="float")
heatmap_rmse = pd.DataFrame(index=us_corn_datasets, columns=scv_methods, dtype="float")

for sampled_data in tqdm(us_corn_datasets):
    real_rank = pd.read_csv(os.path.join(root_path, sampled_data, "out_of_sample_error.csv"))
    real_rank["inverse_rank"] = 11 - real_rank["rank"]
    real_rank["weight"] = real_rank["inverse_rank"]/10
    max_dist_rank = sum(real_rank["weight"] * (real_rank["rank"] - real_rank["inverse_rank"])**2)
    sampled_rank = pd.read_csv(os.path.join(root_path, sampled_data, "comparison", "Rank.csv"))
    sampled_mse = pd.read_csv(os.path.join(root_path, sampled_data, "comparison", "RMSE.csv"))
    for scv in scv_methods:
        dist_rank = sum(real_rank["weight"] * (real_rank["rank"] - sampled_rank[scv])**2)/max_dist_rank
        #diff_rmse = real_rank["rmse"] - sampled_mse[scv]
        heatmap_data.loc[sampled_data, scv] = dist_rank

cmap = sns.cm.rocket_r
sns.heatmap(heatmap_data, cmap=cmap)
heatmap_data
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 68.33it/s]
#                                       CrossValidation  Optimistic  \
# US_Corn_Yield_2016_Removed_Northeast         0.490358    0.393388
# US_Corn_Yield_2016_Removed_Southeast         0.305234    0.263361
# US_Corn_Yield_2016_Removed_Midwest           0.575207    0.381818
# US_Corn_Yield_2016_Removed_Southwest         0.174105    0.155923
# US_Corn_Yield_2016_Removed_West              0.159780    0.127824
#
#                                       RegGBSCV_R_Kappa_0.0  \
# US_Corn_Yield_2016_Removed_Northeast              0.214876
# US_Corn_Yield_2016_Removed_Southeast              0.206612
# US_Corn_Yield_2016_Removed_Midwest                0.729477
# US_Corn_Yield_2016_Removed_Southwest              0.223140
# US_Corn_Yield_2016_Removed_West                   0.171350
#
#                                       RegGBSCV_R_Kappa_0.1  \
# US_Corn_Yield_2016_Removed_Northeast              0.264463
# US_Corn_Yield_2016_Removed_Southeast              0.238017
# US_Corn_Yield_2016_Removed_Midwest                0.663912
# US_Corn_Yield_2016_Removed_Southwest              0.228099
# US_Corn_Yield_2016_Removed_West                   0.176860
#
#                                       RegGBSCV_R_Kappa_0.2  \
# US_Corn_Yield_2016_Removed_Northeast              0.326722
# US_Corn_Yield_2016_Removed_Southeast              0.238017
# US_Corn_Yield_2016_Removed_Midwest                0.609917
# US_Corn_Yield_2016_Removed_Southwest              0.263912
# US_Corn_Yield_2016_Removed_West                   0.221488
#
#                                       RegGBSCV_R_Kappa_0.3  \
# US_Corn_Yield_2016_Removed_Northeast              0.320661
# US_Corn_Yield_2016_Removed_Southeast              0.238017
# US_Corn_Yield_2016_Removed_Midwest                0.610468
# US_Corn_Yield_2016_Removed_Southwest              0.245730
# US_Corn_Yield_2016_Removed_West                   0.258402
#
#                                       RegGBSCV_R_Kappa_0.4  \
# US_Corn_Yield_2016_Removed_Northeast              0.272176
# US_Corn_Yield_2016_Removed_Southeast              0.330579
# US_Corn_Yield_2016_Removed_Midwest                0.580165
# US_Corn_Yield_2016_Removed_Southwest              0.238567
# US_Corn_Yield_2016_Removed_West                   0.265565
#
#                                       RegGBSCV_R_Kappa_0.5  \
# US_Corn_Yield_2016_Removed_Northeast              0.331129
# US_Corn_Yield_2016_Removed_Southeast              0.330579
# US_Corn_Yield_2016_Removed_Midwest                0.595592
# US_Corn_Yield_2016_Removed_Southwest              0.317906
# US_Corn_Yield_2016_Removed_West                   0.289256
#
#                                       RegGBSCV_R_Kappa_0.6  \
# US_Corn_Yield_2016_Removed_Northeast              0.371901
# US_Corn_Yield_2016_Removed_Southeast              0.314050
# US_Corn_Yield_2016_Removed_Midwest                0.595592
# US_Corn_Yield_2016_Removed_Southwest              0.332231
# US_Corn_Yield_2016_Removed_West                   0.289256
#
#                                       RegGBSCV_R_Kappa_0.7  \
# US_Corn_Yield_2016_Removed_Northeast              0.343251
# US_Corn_Yield_2016_Removed_Southeast              0.323416
# US_Corn_Yield_2016_Removed_Midwest                0.575207
# US_Corn_Yield_2016_Removed_Southwest              0.339394
# US_Corn_Yield_2016_Removed_West                   0.274380
#
#                                       RegGBSCV_R_Kappa_0.8  \
# US_Corn_Yield_2016_Removed_Northeast              0.230854
# US_Corn_Yield_2016_Removed_Southeast              0.342700
# US_Corn_Yield_2016_Removed_Midwest                0.580165
# US_Corn_Yield_2016_Removed_Southwest              0.369697
# US_Corn_Yield_2016_Removed_West                   0.266116
#
#                                       RegGBSCV_R_Kappa_0.9  \
# US_Corn_Yield_2016_Removed_Northeast              0.136639
# US_Corn_Yield_2016_Removed_Southeast              0.433609
# US_Corn_Yield_2016_Removed_Midwest                0.749862
# US_Corn_Yield_2016_Removed_Southwest              0.207163
# US_Corn_Yield_2016_Removed_West                   0.274380
#
#                                       RegGBSCV_R_Kappa_1.0  TraditionalSCV
# US_Corn_Yield_2016_Removed_Northeast              0.200000        0.267769
# US_Corn_Yield_2016_Removed_Southeast              0.424242        0.330028
# US_Corn_Yield_2016_Removed_Midwest                0.734435        0.493113
# US_Corn_Yield_2016_Removed_Southwest              0.314050        0.090909
# US_Corn_Yield_2016_Removed_West                   0.240220        0.401653
